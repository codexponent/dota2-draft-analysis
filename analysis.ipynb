# %%
import dota2api
import numpy as np
import pandas as pd

# %%
API_KEY = '2029A39ECAAB627B5F71CF4C3E30F72D'
api = dota2api.Initialise(API_KEY)

# %%
try:
    match = api.get_match_details(match_id=1000193456)
except dota2api.src.exceptions.APIError as error:
    print(error)
print(match['lobby_name'])
print(match['lobby_type'])
print(match['game_mode'])
# Out:
# Practice
# 1
# 16

# %%
match
# Out:
# {'players': [{'account_id': 21265941,
#    'player_slot': 0,
#    'hero_id': 23,
#    'item_0': 188,
#    'item_1': 1,
#    'item_2': 50,
#    'item_3': 149,
#    'item_4': 185,
#    'item_5': 46,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'kills': 6,
#    'deaths': 5,
#    'assists': 5,
#    'leaver_status': 0,
#    'last_hits': 87,
#    'denies': 5,
#    'gold_per_min': 354,
#    'xp_per_min': 387,
#    'level': 15,
#    'hero_name': 'Kunkka',
#    'item_0_name': 'Smoke of Deceit',
#    'item_1_name': 'Blink Dagger',
#    'item_2_name': 'Phase Boots',
#    'item_3_name': 'Crystalys',
#    'item_4_name': 'Drum of Endurance',
#    'item_5_name': 'Town Portal Scroll',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 44513538,
#    'player_slot': 1,
#    'hero_id': 103,
#    'item_0': 102,
#    'item_1': 86,
#    'item_2': 46,
#    'item_3': 178,
#    'item_4': 214,
#    'item_5': 0,
# ...

# %%
# # # Getting Heroes ID according to the name
heroes = api.get_heroes()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/software/anaconda3/envs/dotaenv36/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~/software/anaconda3/envs/dotaenv36/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      55
# ---> 56     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      57         af, socktype, proto, canonname, sa = res
#
# ~/software/anaconda3/envs/dotaenv36/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
# heroes

# %%
# # Getting 10 matches
try:
    match = api.get_match_details(match_id=1000193456)
except dota2api.src.exceptions.APIError as error:
    print(error)
print(match['lobby_name'])
print(match['lobby_type'])
print(match['game_mode'])

# %%
# api.get_match_history_by_seq_num(start_at_match_seq_num=1000)
